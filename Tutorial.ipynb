# %%
import pandas as pd

# %%
# configure git
# !git config --global user.email "anjaliancy.a@gmail.com"
# !git config --global user.name "Anjali Ancy"

# clone your repo (change owner/repo and branch if needed)
# !git clone https://github.com/anjaliancy/tutorial.git
# Out:
# Cloning into 'tutorial'...
# ...

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Okay!")
# Out:
# Okay!

# %%
print("40+2")
# Out:
# 40+2

# %%
# if your notebook is in /content, copy it into the cloned repo
# !cp /content/Tutorial.ipynb tutorial/
# Out:
# cp: cannot stat '/content/Tutorial.ipynb': No such file or directory

# %% [markdown]
# First, let's create a simple `README.md` file in the `tutorial` directory.
